# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode, col
import pandas as pd
import os

# %%
spark = SparkSession.builder \
    .appName("RecommenderDemo") \
    .master(os.environ.get("SPARK_MASTER", "local[*]")) \
    .config("spark.executor.memory", "4g") \
    .config("spark.driver.memory", "4g") \
    .getOrCreate()

# %%
RECOMMENDATION_PATH = "hdfs://namenode:9000/recommendations/batch_top10"
METADATA_PATH = "hdfs://namenode:9000/data/movies_metadata.csv"

# %%
def load_recommendations(recommendations_path):
    user_recs = spark.read.parquet(recommendations_path)
    user_recs.printSchema()
    
    recs_exp = (
        user_recs
        .withColumn("rec", explode(col("recommendations")))
        .select(
            col("user_id"),
            col("rec.movie_id").alias("movie_id"),
            col("rec.rating").alias("score")
        )
    )
    return recs_exp.toPandas()

def load_metadata(metadata_path):
    movies_metadata = spark.read.csv(metadata_path, header=True, inferSchema=True)
    movies_metadata.printSchema()
    
    selected_metadata = (
        movies_metadata
        .select(
            col("id").alias("movie_id"),
            col("name").alias("title"),
            col("genres")
        )
    )
    
    return selected_metadata.toPandas()

# %%
recommendations_pd = load_recommendations(RECOMMENDATION_PATH)
metadata_pd = load_metadata(METADATA_PATH)
# Out:
# root
#  |-- user_id: integer (nullable = true)
#  |-- recommendations: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- movie_id: integer (nullable = true)
#  |    |    |-- rating: float (nullable = true)
#
# root
#  |-- id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- genres: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- IMDb_score: double (nullable = true)
#  |-- MoMo_score: double (nullable = true)

# %%
recommendations_pd
# Out:
#         user_id  movie_id     score
# 0             2         1  9.895300
# 1             2       268  6.122416
# 2             2       220  6.048351
# 3             2       640  6.013707
# 4             2       649  5.904694
# ...         ...       ...       ...
# 865415   101055       239  9.422239
# 865416   101055       464  9.413363
# 865417   101055       566  9.215281
# 865418   101055       282  9.205427
# 865419   101055       780  9.199791
#
# [865420 rows x 3 columns]

# %%
metadata_pd
# Out:
#      movie_id                                  title  \
# 0           1               Marita: Vong Nữ Đoạt Hồn
# 1           2                            Giờ Thả Máu
# 2           3                       Nắm Đấm Trời Ban
# 3           4  Cô Gái Năm Ấy Chúng Ta Từng Theo Đuổi
# 4           5         GIA ĐÌNH x ĐIỆP VIÊN MÃ: TRẮNG
# ..        ...                                    ...
# 849       850              Những Đứa Trẻ Trong Sương
# 850       851  Thanh Xuân 18×2: Lữ Trình Hướng Về Em
# 851       852                             Madame Web
# 852       853            Domino: Lối Thoát Cuối Cùng
# 853       854                Lật Mặt 7: Một Điều Ước
#
#                                    genres
# 0                                 Kinh dị
# 1                        Gay cấn, Kinh dị
# 2                          Hài, Hành động
# 3               Chính kịch, Hài, Lãng mạn
# 4    Phiêu lưu, Hài, Hành động, Hoạt hình
# ..                                    ...
# 849                              Tài liệu
# 850                              Lãng mạn
# 851      Khoa học - Viễn tưởng, Hành động
# 852           Tâm lý, Tội phạm, Hành động
# 853               Gia đình, Tình cảm, Hài
#
# [854 rows x 3 columns]

# %%
user_ids = recommendations_pd['user_id'].unique()
selected_user = 36

# MERGE 2 TABLES RECOMMENDATIONS AND METADATA
recommendations_pd["movie_id"] = recommendations_pd["movie_id"].astype(str)
metadata_pd["movie_id"] = metadata_pd["movie_id"].astype(str)

merged_pd = recommendations_pd.merge(
    metadata_pd[['movie_id', 'title', 'genres']],
    on="movie_id",
    how="inner"
)

user_recs = merged_pd[merged_pd['user_id'] == selected_user]
top_n = 10
top_recs = user_recs.sort_values("score", ascending=False).head(top_n)

top_recs
# Out:
#         user_id movie_id     score  \
# 86712        36      814  9.979370
# 100054       36      274  9.877183
# 103411       36      754  9.757500
# 103741       36      776  9.707589
# 2            36        1  9.619936
# 104004       36      556  9.062175
# 107794       36      259  9.000944
# 2904         36      438  8.893117
# 108213       36       74  8.813324
# 108265       36      711  8.579103
#
#                                                     title  \
# 86712   Phim Shin Cậu Bé Bút Chì: Nóng Bỏng Tay! Những...
# 100054  Phim Shin Cậu Bé Bút Chì: Bí Ẩn! Học Viện Hoa ...
# 103411                                  Trốn Chạy Tử Thần
# 103741  3DCG! SHIN - CẬU BÉ BÚT CHÌ: ĐẠI CHIẾN SIÊU NĂ...
# 2                                Marita: Vong Nữ Đoạt Hồn
# 104004                                  Bí Kíp Luyện Rồng
# 107794                                            Xì Trum
# 2904                                  Nhà Có Năm Nàng Dâu
# 108213                                            Mộng Du
# 108265                           Lật Mặt 8: Vòng Tay Nắng
#
#                                            genres
# 86712                          Âm Nhạc, Hoạt hình
# 100054                                  Hoạt hình
# 103411  Gay cấn, Khoa học - Viễn tưởng, Hành động
# 103741                                  Hoạt hình
# 2                                         Kinh dị
# 104004  Gia đình, Phiêu lưu, Giả tưởng, Hành động
# 107794             Gia đình, Giả tưởng, Hoạt hình
# 2904                     Hài, Lãng mạn, Hoạt hình
# 108213                     Bí ẩn, Kinh dị, Tâm lý
# 108265              Chính kịch, Gia đình, Âm Nhạc

# %%
spark.stop()
